# %% [markdown]
# ###Becca's Notebook
# ####Using bigquery to read in HackerNews df. Cleaning and preprocessing for use with vaderSentiment model.

# %%
import sys, os
cwd = os.getcwd()
sys.path[0] = cwd[:cwd.rfind('/')]

# %%
#Imports
import os
import numpy as np
import pandas as pd

from google.cloud import bigquery

# %%
#Google cloud credentials
os.environ['GOOGLE_APPLICATION_CREDENTIALS']='/content/Saltiest HN Trolls.json'

# Create a "Client" object
client = bigquery.Client()

# Bigquery dataset reference
hn_ref = client.dataset('hacker_news', project='hn-dataset')

# %%
# Run SQL query to obtain filtered table
query_string = """
SELECT C.by
FROM (
  SELECT A.by, COUNT(*) AS count
  FROM `bigquery-public-data.hacker_news.full` AS A
  GROUP BY A.by
  ORDER BY count DESC
  LIMIT 100
) AS C
WHERE C.by != "None"
"""

frequent_users = client.query(query_string).result().to_dataframe()

# %%
# This is a triple-nested query that gets a number of comments made only by the most
# frequent users.  Change the "LIMIT XXX" part of the inner-most query to tune the
# number of users.  Change the outermost "LIMIT YYY" to change the total number of comments.
query_string = """
SELECT *
FROM `bigquery-public-data.hacker_news.full` AS A
WHERE A.by IN (
  SELECT C.by
  FROM (
    SELECT A.by, COUNT(*) AS count
    FROM `bigquery-public-data.hacker_news.full` AS A
    GROUP BY A.by
    ORDER BY count DESC
    LIMIT 500
  ) AS C
  WHERE C.by != "None"
)
LIMIT 5000
"""

df = client.query(query_string).result().to_dataframe()

# %%
# filter out by type (keep story and comment)
df[(df['type'] == 'story') | (df['type'] == 'comment')]
# Out:
#                                                   title  ... deleted
# 0                                                  None  ...    None
# 1                                                  None  ...    None
# 2                                                  None  ...    None
# 3                                                  None  ...    None
# 4                                                  None  ...    None
# ...                                                 ...  ...     ...
# 4995                                               None  ...    None
# 4996                                               None  ...    None
# 4997                  Nuts Are a Nutritional Powerhouse  ...    None
# 4998                                               None  ...    None
# 4999  Bitcoin expert scams a scammer, donates the mo...  ...    None
#
# [4991 rows x 14 columns]

# %%
# drop some columns
#drop title, has 447,218 null values 
#drop ranking, has 500000 null values
#drop score, has 446968 null values 
clean_df = df.drop(['time', 'descendants', 'deleted', 'url', 'dead', 'title', 'ranking', 'score'], axis=1)

# %%
#only 507 comments with 5 characters or less, upon analysis doesn't look like they provide much context, 
#not helpful for model analysis so drop comments with 5 words or less

# take only the rows whose text column's length is greater than five
# this also removes the texts that are None
clean_df = clean_df[clean_df['text'].str.len() > 5]

# %%
# Use BS on a single piece of text to remove strange chars and URLs and tags
from bs4 import BeautifulSoup

def clean_soup(text):
    # make a soup - this takes care of strange characters
    soup = BeautifulSoup(text, "html.parser")

    # delete <a> tags as they contain URLs -- remember <a href="url_here">
    # tags contain URLs
    for s in soup.select('a'):
       s.extract()

    # the soup contains <p> tags -- here we get rid of those and join them with spaces
    strings = soup.find_all(text=True, recursive=True)
    result = ' '.join(strings)

    return result

# %%
# Apply that to each comment/story text
clean_text = clean_df['text'].apply(clean_soup)

# %%
clean_df['text'] = clean_text

# %%
import pandas as pd
pd.options.display.max_colwidth = 100
clean_df.sample(10)
# Out:
#                                                                                                      text  ...      parent
# 1804  This has always struck me as a weak justification. If readers value succinctness, the problem sh...  ...   6174676.0
# 4404  I think the core complaint, though, is that people's first step should be "search using a genera...  ...   7692310.0
# 419   > The UK seems to have a flexible attitude as to whether a false rape accusation should be consi...  ...  19779520.0
# 3968  At St. Pancras, it's not just security. You're clearing EU immigration as well. They don't do an...  ...  16364786.0
# 4205  If you do get seriously sick, your family members would not be able to visit you anyway so it do...  ...  22704560.0
# 2294  I would joke about adding a hyperloop between Reno and the Bay Area :-) Actually rail is pretty ...  ...   8265924.0
# 4555  It may well be. Not sure if i can produce a link off hand. But Poettering seems to be on record ...  ...  11783896.0
# 1844  For what it's worth, the initial EJB spec was written by IBM, so I guess the answer to your ques...  ...  13645270.0
# 2892  I guess I shouldn't mention the coffee shops I know that simply refrigerate their hour-old coffe...  ...   1391026.0
# 4049                                                                      It’s the local tv news station.  ...  19989988.0
#
# [10 rows x 6 columns]

# %%
#makes sense the parent would have some null values, if they are the first comment
clean_df.isnull().sum()
# Out:
# text          0
# by            0
# timestamp     0
# type          0
# id            0
# parent       12
# dtype: int64

# %% [markdown]
# ###Pyrom's Notebook
# ####Using vaderSentiment to produce 'Saltiness' score for each Username. The higher the score, the more salty.
#
# ####VADERSentiment is a pretrained model that processes texts and calculates their sentiment values.

# %%
pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.6/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from vaderSentiment) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->vaderSentiment) (2.9)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
#Panda Settings
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %%
#Drop misc columns
df = clean_df.drop(columns=['timestamp', 'type', 'parent'])
#Convert to string values
df = df.astype(str)
df.head()
# Out:
#                                                                                                   text  \
# 0                                                                                              Thanks!
# 1  Ah. To summarise those some previous companies, Timbercorp and Great Southern pushed planting si...
# 2  > which are not official standards It depends on what you mean by 'official standards.' We've re...
# 3  If you consider child rape and industrial employment to be in the same category then you're not ...
# 4  >> "If someone wants to mess with you they can just keep calling you and your only choice is to ...
#
#              by        id
# 0  AnimalMuppet   7525035
# 1        tim333  20599530
# 2  steveklabnik   9597558
# 3     anigbrowl  15195872
# 4     k-mcgrady  11835749

# %%
#Slim out users with less than 1000 comments, more manageable, cuts data in half
def slim(df):
    """
    Slim out dataset to user with 1000 or more comments.

    Returns a filtered dataframe.
    """

    X = df.copy()
    X = X.groupby('by').filter(lambda x: x['by'].count()<50)

    return X

# %%
#Apply function
new_df = slim(df)
print(new_df.shape)
new_df.head()
# Out:
# (4391, 3)
#                                                                                                   text  \
# 0                                                                                              Thanks!
# 1  Ah. To summarise those some previous companies, Timbercorp and Great Southern pushed planting si...
# 2  > which are not official standards It depends on what you mean by 'official standards.' We've re...
# 3  If you consider child rape and industrial employment to be in the same category then you're not ...
# 4  >> "If someone wants to mess with you they can just keep calling you and your only choice is to ...
#
#              by        id
# 0  AnimalMuppet   7525035
# 1        tim333  20599530
# 2  steveklabnik   9597558
# 3     anigbrowl  15195872
# 4     k-mcgrady  11835749

# %%
#Machine Learning, using VADER Sentiment Analysis
def sentiment_score(comment):
    analyser = SentimentIntensityAnalyzer()
    
    x = 0
    score = analyser.polarity_scores(comment)
    x = x + score['pos']
    x = x + score['compound']
    x = x - score['neg'] 

    return x

# %%
#Apply function to 'text' column
new_df['Saltiness'] = new_df['text'].apply(sentiment_score)
new_df.head()
# Out:
#                                                                                                   text  \
# 0                                                                                              Thanks!
# 1  Ah. To summarise those some previous companies, Timbercorp and Great Southern pushed planting si...
# 2  > which are not official standards It depends on what you mean by 'official standards.' We've re...
# 3  If you consider child rape and industrial employment to be in the same category then you're not ...
# 4  >> "If someone wants to mess with you they can just keep calling you and your only choice is to ...
#
#              by        id  Saltiness
# 0  AnimalMuppet   7525035     1.4926
# 1        tim333  20599530     0.8410
# 2  steveklabnik   9597558     0.5879
# 3     anigbrowl  15195872    -0.9846
# 4     k-mcgrady  11835749     0.1400

# %%
import copy
sentiment_df = copy.copy(new_df)

# %%
#Generate User_ID
new_df['User_ID'] = new_df.groupby(new_df.by.tolist(), sort=False).ngroup() + 1000
new_df.head()
# Out:
#                                                                                                   text  \
# 0                                                                                              Thanks!
# 1  Ah. To summarise those some previous companies, Timbercorp and Great Southern pushed planting si...
# 2  > which are not official standards It depends on what you mean by 'official standards.' We've re...
# 3  If you consider child rape and industrial employment to be in the same category then you're not ...
# 4  >> "If someone wants to mess with you they can just keep calling you and your only choice is to ...
#
#              by        id  Saltiness  User_ID
# 0  AnimalMuppet   7525035     1.4926     1000
# 1        tim333  20599530     0.8410     1001
# 2  steveklabnik   9597558     0.5879     1002
# 3     anigbrowl  15195872    -0.9846     1003
# 4     k-mcgrady  11835749     0.1400     1004

# %%
new_df.sort_values(by='by')
# Out:
#                                                                                                      text  \
# 3547              That  is a cool feature. good use of instant torque. offsets the inertia during windup.
# 1209  This is a good point, and also its worth another note (from the linked article): Palihapitiya pu...
# 4081                                             Odd comment, in this context. Have you read the article?
# 4243  Be wary of conflating corporate cash with the LP cash backing VC companies. Companies are holdin...
# 1126  Its also shorter to write/speak, than the generic & generally non-sensical altenative: "smartpho...
# ...                                                                                                   ...
# 3858  I didn't think disk io matters all that much if you fit your data in memory, which afaik you sho...
# 1652          On AWS can't you just use ACM which is supposed to be pretty painless Doesn't seem that bad
# 3706            Intel products are heavily segmented. Did you do your comparison within the same segment?
# 4134       Just curious, has anyone on HN ever successfully claimed money from SSL certificate insurance?
# 2261  I think it works like this: Intel develops a CPU and looks at the market and sees that their chi...
#
#           by        id  Saltiness  User_ID
# 3547  001sky   7543035     0.9229     1362
# 1209  001sky   6487404     0.7607     1362
# 4081  001sky  10611359    -0.5222     1362
# 4243  001sky   7642538     0.9849     1362
# 1126  001sky   4740584     0.0000     1362
# ...      ...       ...        ...      ...
# 3858  zokier   3947657     0.6044     1368
# 1652  zokier  17601788     1.1597     1368
# 3706  zokier  14539257     0.0000     1368
# 4134  zokier  11130508     0.9845     1368
# 2261  zokier   1705864     0.0197     1368
#
# [4391 rows x 5 columns]

# %%
print("Max User_ID:", new_df['User_ID'].max())
# Out:
# Max User_ID: 1481

# %%
new_df = new_df[(new_df['Saltiness'] >= 0) & (new_df['Saltiness'] <= 1.1)]
new_df.head()
# Out:
#                                                                                                   text  \
# 1  Ah. To summarise those some previous companies, Timbercorp and Great Southern pushed planting si...
# 2  > which are not official standards It depends on what you mean by 'official standards.' We've re...
# 4  >> "If someone wants to mess with you they can just keep calling you and your only choice is to ...
# 5  Makes sense. I guess my central confusion is that I thought the  entire  reason for bundling mor...
# 8  Many programming languages use references to other objects liberally. Wouldn't it be hard to kee...
#
#              by        id  Saltiness  User_ID
# 1        tim333  20599530     0.8410     1001
# 2  steveklabnik   9597558     0.5879     1002
# 4     k-mcgrady  11835749     0.1400     1004
# 5        ethbro  10352663     1.0750     1005
# 8   icebraining  14891742     0.4923     1007

# %%
new_df.describe()
# Out:
#          Saltiness      User_ID
# count  2811.000000  2811.000000
# mean      0.513725  1203.707222
# std       0.370580   131.843510
# min       0.000000  1000.000000
# 25%       0.139900  1085.000000
# 50%       0.542600  1191.000000
# 75%       0.851650  1313.000000
# max       1.099500  1481.000000

# %%
#Rename columns
new_df.columns = ['Comment', 'Username', 'Comment_ID', 'Saltiness', 'User_ID']

#Rearrange columns, sort by ranking
order = ['Comment_ID', 'User_ID', 'Username', 'Comment', 'Saltiness']
comments_score = new_df[order]

#Housekeeping
comments_score.sort_values(by=['Username'], inplace=True)
comments_score = comments_score.reset_index()
comments_score = comments_score.drop(columns=['index'])
comments_score
# Out:
#      Comment_ID  User_ID Username  \
# 0       7642538     1362   001sky
# 1       8015406     1362   001sky
# 2       7543035     1362   001sky
# 3       6487404     1362   001sky
# 4       6447899     1362   001sky
# ...         ...      ...      ...
# 2806   11130508     1368   zokier
# 2807    6192785     1368   zokier
# 2808    4915255     1368   zokier
# 2809    3947657     1368   zokier
# 2810    1705864     1368   zokier
#
#                                                                                                   Comment  \
# 0     Be wary of conflating corporate cash with the LP cash backing VC companies. Companies are holdin...
# 1     Looks that way...? And not just p.1, for the first ~60 stories there is not much newer than the ...
# 2                 That  is a cool feature. good use of instant torque. offsets the inertia during windup.
# 3     This is a good point, and also its worth another note (from the linked article): Palihapitiya pu...
# 4     This is also pretty easy to do today with an ear-piece and a Garmin. Heads up is only really hel...
# ...                                                                                                   ...
# 2806       Just curious, has anyone on HN ever successfully claimed money from SSL certificate insurance?
# 2807  Zimmermann advocating Hushmail. That's curious. Also imho deleting user data without warning is ...
# 2808  basically by replacing utilman you can execute arbitrary code with system(?) privileges? does th...
# 2809  I didn't think disk io matters all that much if you fit your data in memory, which afaik you sho...
# 2810  I think it works like this: Intel develops a CPU and looks at the market and sees that their chi...
#
#       Saltiness
# 0        0.9849
# 1        0.0000
# 2        0.9229
# 3        0.7607
# 4        0.9789
# ...         ...
# 2806     0.9845
# 2807     0.4200
# 2808     1.0092
# 2809     0.6044
# 2810     0.0197
#
# [2811 rows x 5 columns]

# %%
#Create copy for clean table for salty_user
import copy
users_score = copy.copy(new_df)
users_score.head()
# Out:
#                                                                                                Comment  \
# 1  Ah. To summarise those some previous companies, Timbercorp and Great Southern pushed planting si...
# 2  > which are not official standards It depends on what you mean by 'official standards.' We've re...
# 4  >> "If someone wants to mess with you they can just keep calling you and your only choice is to ...
# 5  Makes sense. I guess my central confusion is that I thought the  entire  reason for bundling mor...
# 8  Many programming languages use references to other objects liberally. Wouldn't it be hard to kee...
#
#        Username Comment_ID  Saltiness  User_ID
# 1        tim333   20599530     0.8410     1001
# 2  steveklabnik    9597558     0.5879     1002
# 4     k-mcgrady   11835749     0.1400     1004
# 5        ethbro   10352663     1.0750     1005
# 8   icebraining   14891742     0.4923     1007

# %%
#Convert Saltiness column to percent
comments_score['Saltiness'] = comments_score['Saltiness'].apply('{:.0%}'.format)

#Moment of truth!
comments_score.head()
# Out:
#   Comment_ID  User_ID Username  \
# 0    7642538     1362   001sky
# 1    8015406     1362   001sky
# 2    7543035     1362   001sky
# 3    6487404     1362   001sky
# 4    6447899     1362   001sky
#
#                                                                                                Comment  \
# 0  Be wary of conflating corporate cash with the LP cash backing VC companies. Companies are holdin...
# 1  Looks that way...? And not just p.1, for the first ~60 stories there is not much newer than the ...
# 2              That  is a cool feature. good use of instant torque. offsets the inertia during windup.
# 3  This is a good point, and also its worth another note (from the linked article): Palihapitiya pu...
# 4  This is also pretty easy to do today with an ear-piece and a Garmin. Heads up is only really hel...
#
#   Saltiness
# 0       98%
# 1        0%
# 2       92%
# 3       76%
# 4       98%

# %%
#Not too salty comment
print(comments_score.loc[100,'Comment'])
print(comments_score.loc[100,'Saltiness'])
# Out:
# You're welcome : ) I voted you up just based on all the crowd-voting going on. Sorry about misrepresenting your post. It had been a while since you posted it, and it's gone now.
# 45%

# %%
#Comment is salty
print(comments_score.loc[50,'Comment'])
print(comments_score.loc[50,'Saltiness'])
# Out:
# Read the docket (posted up thread), but generally shareholders are debtors-in-possesion meaning they are "owed" a fraction of the company if they sold their shares. Everyone who has a share of American Apparel is listed on that docket as a creditor. As for board seats, I can't say. I've watched a couple of large companies restructure fairly closely but don't recall board seats being offered as part of that. Certainly at the point of being in Chapter 11 bankruptcy you're no longer the company you once were, one option is always to liquidate and move to Chapter 7 to disperse the assets. We had a customer company do that (one of the baby telephone companies) in the dot com bust when I was at Tut/FreeGate. As I recall from that transaction we got a check for around $3,000 for what had been something like $1.2M worth of networking gear they had deployed and not yet paid for.
# 98%

# %%
comments_score.describe()
# Out:
#            User_ID
# count  2811.000000
# mean   1203.707222
# std     131.843510
# min    1000.000000
# 25%    1085.000000
# 50%    1191.000000
# 75%    1313.000000
# max    1481.000000

# %%
#Push salty_comment table to postgres
#Establish connection to database
from sqlalchemy import create_engine
engine = create_engine('postgres://aecqvjqa:JTG9-DH2xUSvObwIc98hFfw3PpzQZHJo@ruby.db.elephantsql.com:5432/aecqvjqa')
comments_score.to_sql("salty_comment", engine, if_exists='replace')
# Out:
# /usr/local/lib/python3.6/dist-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
#Salty Users, create table of Saltiness score total by username
users_score = copy.copy(new_df)
users_score.head()
# Out:
#                                                                                                Comment  \
# 1  Ah. To summarise those some previous companies, Timbercorp and Great Southern pushed planting si...
# 2  > which are not official standards It depends on what you mean by 'official standards.' We've re...
# 4  >> "If someone wants to mess with you they can just keep calling you and your only choice is to ...
# 5  Makes sense. I guess my central confusion is that I thought the  entire  reason for bundling mor...
# 8  Many programming languages use references to other objects liberally. Wouldn't it be hard to kee...
#
#        Username Comment_ID  Saltiness  User_ID
# 1        tim333   20599530     0.8410     1001
# 2  steveklabnik    9597558     0.5879     1002
# 4     k-mcgrady   11835749     0.1400     1004
# 5        ethbro   10352663     1.0750     1005
# 8   icebraining   14891742     0.4923     1007

# %%
#Drop comment column
users_score.drop(columns=['Comment_ID', 'Comment'], inplace=True)
users_score.head()
# Out:
#        Username  Saltiness  User_ID
# 1        tim333     0.8410     1001
# 2  steveklabnik     0.5879     1002
# 4     k-mcgrady     0.1400     1004
# 5        ethbro     1.0750     1005
# 8   icebraining     0.4923     1007

# %%
#Groupby username
users_score = users_score.groupby('Username', as_index=False).mean()
users_score.head(10)
# Out:
#         Username  Saltiness  User_ID
# 0         001sky   0.623125     1362
# 1       Alex3917   0.611640     1377
# 2  AndrewKemendo   0.542400     1465
# 3   AnimalMuppet   0.328600     1000
# 4        Animats   0.414171     1065
# 5         Anon84   0.459800     1421
# 6   AnthonyMouse   0.605333     1053
# 7     Apocryphon   0.000000     1474
# 8    AstralStorm   0.229500     1251
# 9    BurningFrog   0.337450     1329

# %%
#Convert Saltiness column to percent
users_score['Saltiness'] = users_score['Saltiness'].apply('{:.0%}'.format)

#Second moment of truth!
users_score.head()
# Out:
#         Username Saltiness  User_ID
# 0         001sky       62%     1362
# 1       Alex3917       61%     1377
# 2  AndrewKemendo       54%     1465
# 3   AnimalMuppet       33%     1000
# 4        Animats       41%     1065

# %%
#Rearrange columns
order = ['User_ID', 'Username', 'Saltiness']
users_score = users_score[order]
users_score
# Out:
#      User_ID       Username Saltiness
# 0       1362         001sky       62%
# 1       1377       Alex3917       61%
# 2       1465  AndrewKemendo       54%
# 3       1000   AnimalMuppet       33%
# 4       1065        Animats       41%
# ..       ...            ...       ...
# 470     1360         yuhong       48%
# 471     1408   yummyfajitas       55%
# 472     1179          zanny       88%
# 473     1020         zaroth       55%
# 474     1368         zokier       51%
#
# [475 rows x 3 columns]

# %%
#Push salty_user table to postgres
users_score.to_sql("salty_user", engine, if_exists='replace')
